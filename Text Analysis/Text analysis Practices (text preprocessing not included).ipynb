# %%
# !pip install wordcloud
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
import os
data = pd.read_csv("./data/sentiment.csv")

data.head(10)
# Out:
#                                                 text Sentiment
# 0            حقوق المرأة 💚💚💚 https://t.co/Mzf90Ta5g1  positive
# 1  RT @___IHAVENOIDEA: حقوق المرأة في الإسلام. ht...  positive
# 2  RT @saud_talep: Retweeted لجنة التنمية بشبرا (...  positive
# 3  RT @MojKsa: حقوق المرأة التي تضمنها لها وزارة ...  positive
# 4  RT @abm112211: ولي امر الزوجة او ولي الزوجة او...  positive
# 5  RT @fatemaar7: انا كامرأة يوجعني كل حزن نساء ا...  positive
# 6  @Samar_K_ 😂😂😂😂😂\n اومن حقوق المرأة \n أنك تفتح...  positive
# 7  @AliFCD @ShamsanM @AlyemenNor @space_dist @m2r...  positive
# 8        مبدائيا انا مع حقوق المرأة وضد حقوق الرجل 😁  positive
# 9  RT @Dresraamohammed: السؤال بقى للناس الي شغال...  positive

# %%
sns.countplot(data["Sentiment"])

# %%
wordcloud = WordCloud(max_font_size = 60, max_words = 100, background_color = "black").generate(str(data.text))
plt.imshow(wordcloud)

# %%
data["Sentiment"].value_counts().plot(kind = 'pie', explode = [0,0.1], figsize = (6,6), autopct = '%1.1f%%', shadow = True)

plt.ylabel("Negative and Positive")
plt.legend(["positive", "negative"])
plt.show()
